# %%
import pandas as pd

# %%
df=pd.read_csv('../datasets/players_data-2024_2025.csv')

# %%
df.head(n=10)
# Out:
#    Rk               Player   Nation    Pos          Squad                Comp  \
# 0   1           Max Aarons  eng ENG     DF    Bournemouth  eng Premier League
# 1   2           Max Aarons  eng ENG  DF,MF       Valencia          es La Liga
# 2   3       Rodrigo Abajas   es ESP     DF       Valencia          es La Liga
# 3   4       James Abankwah   ie IRL  DF,MF        Udinese          it Serie A
# 4   5    Keyliane Abdallah   fr FRA     FW      Marseille          fr Ligue 1
# 5   6     Yunis Abdelhamid   ma MAR     DF  Saint-Étienne          fr Ligue 1
# 6   7        Himad Abdelli   dz ALG  MF,FW         Angers          fr Ligue 1
# 7   8  Mohamed Abdelmoneim   eg EGY     DF           Nice          fr Ligue 1
# 8   9             Ali Abdi   tn TUN  DF,MF           Nice          fr Ligue 1
# 9  10      Saud Abdulhamid   sa KSA     DF           Roma          it Serie A
#
#     Age    Born  MP  Starts  ...  Att (GK)  Thr  Launch%  AvgLen  Opp  Stp  \
# 0  25.0  2000.0   3       1  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 1  25.0  2000.0   2       1  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 2  21.0  2003.0   1       1  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 3  21.0  2004.0   6       0  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 4  19.0  2006.0   1       0  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 5  37.0  1987.0  13      11  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 6  25.0  1999.0  26      26  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 7  26.0  1999.0  10       8  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 8  31.0  1993.0  20      13  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 9  25.0  1999.0   4       2  ...       NaN  NaN      NaN     NaN  NaN  NaN
#
#    Stp%  #OPA  #OPA/90  AvgDist
# 0   NaN   NaN      NaN      NaN
# 1   NaN   NaN      NaN      NaN
# 2   NaN   NaN      NaN      NaN
# 3   NaN   NaN      NaN      NaN
# 4   NaN   NaN      NaN      NaN
# 5   NaN   NaN      NaN      NaN
# 6   NaN   NaN      NaN      NaN
# 7   NaN   NaN      NaN      NaN
# 8   NaN   NaN      NaN      NaN
# 9   NaN   NaN      NaN      NaN
#
# [10 rows x 267 columns]

# %%
df.describe()
# Out:
#                 Rk          Age         Born           MP       Starts  \
# count  2782.000000  2778.000000  2778.000000  2782.000000  2782.000000
# mean   1391.500000    25.805976  1998.526998    15.783968    11.213515
# std     803.238549     4.455373     4.450280     9.378745     9.374105
# min       1.000000    16.000000  1982.000000     1.000000     0.000000
# 25%     696.250000    22.000000  1995.000000     7.000000     2.000000
# 50%    1391.500000    25.500000  1999.000000    17.000000     9.000000
# 75%    2086.750000    29.000000  2002.000000    24.000000    19.000000
# max    2782.000000    42.000000  2008.000000    31.000000    31.000000
#
#                Min          90s          Gls          Ast          G+A  ...  \
# count  2782.000000  2782.000000  2782.000000  2782.000000  2782.000000  ...
# mean   1006.642344    11.183501     1.399353     0.984543     2.383896  ...
# std     796.856386     8.853981     2.676581     1.621983     3.789784  ...
# min       1.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%     273.250000     3.000000     0.000000     0.000000     0.000000  ...
# 50%     870.500000     9.700000     0.000000     0.000000     1.000000  ...
# 75%    1669.500000    18.575000     2.000000     1.000000     3.000000  ...
# max    2790.000000    31.000000    27.000000    17.000000    44.000000  ...
#
#           Att (GK)         Thr     Launch%      AvgLen         Opp  \
# count   196.000000  196.000000  196.000000  196.000000  196.000000
# mean    431.903061   60.479592   34.413776   33.170408  198.275510
# std     338.140762   46.828159   13.696818    5.548124  153.775313
# min       7.000000    0.000000    8.500000   21.800000    2.000000
# 25%     118.750000   16.000000   25.675000   29.500000   56.750000
# 50%     344.000000   52.000000   33.300000   32.300000  154.500000
# 75%     735.750000   99.000000   41.025000   35.925000  342.500000
# max    1256.000000  162.000000   92.300000   56.300000  564.000000
#
#               Stp        Stp%        #OPA     #OPA/90     AvgDist
# count  196.000000  196.000000  196.000000  196.000000  195.000000
# mean    12.392857    6.269388   15.964286    1.154031   14.002564
# std     11.216917    4.049512   15.161819    0.854832    3.939994
# min      0.000000    0.000000    0.000000    0.000000    2.000000
# 25%      3.000000    4.200000    3.000000    0.640000   11.950000
# 50%     10.000000    5.700000   13.000000    1.000000   13.400000
# 75%     19.250000    7.900000   24.000000    1.500000   15.350000
# max     50.000000   33.300000   89.000000    6.130000   32.700000
#
# [8 rows x 222 columns]

# %%
df.shape
# Out:
# (2782, 267)

# %%
print(df.isnull().sum().to_string())
# Out:
# Rk                               0
# Player                           0
# Nation                           3
# Pos                              0
# Squad                            0
# Comp                             0
# Age                              4
# Born                             4
# MP                               0
# Starts                           0
# Min                              0
# 90s                              0
# Gls                              0
# Ast                              0
# G+A                              0
# G-PK                             0
# PK                               0
# PKatt                            0
# CrdY                             0
# CrdR                             0
# xG                               1
# npxG                             1
# xAG                              1
# npxG+xAG                         1
# PrgC                             1
# PrgP                             1
# PrgR                             1
# G+A-PK                           0
# xG+xAG                           1
# Rk_stats_shooting                0
# Nation_stats_shooting            3
# Pos_stats_shooting               0
# Comp_stats_shooting              0
# Age_stats_shooting               4
# Born_stats_shooting              4
# 90s_stats_shooting               0
# Gls_stats_shooting               0
# Sh                               0
# SoT                              0
# SoT%                           513
# Sh/90                            0
# SoT/90                           0
# G/Sh                           513
# G/SoT                          919
# Dist                           513
# FK                               1
# PK_stats_shooting                0
# PKatt_stats_shooting             0
# xG_stats_shooting                1
# npxG_stats_shooting              1
# npxG/Sh                        513
# G-xG                             1
# np:G-xG                          1
# Rk_stats_passing                 0
# Nation_stats_passing             3
# Pos_stats_passing                0
# Comp_stats_passing               0
# Age_stats_passing                4
# Born_stats_passing               4
# 90s_stats_passing                0
# Cmp                              1
# Att                              1
# Cmp%                            18
# TotDist                          1
# PrgDist                          1
# Ast_stats_passing                0
# xAG_stats_passing                1
# xA                               1
# A-xAG                            1
# KP                               1
# 1/3                              1
# PPA                              1
# CrsPA                            1
# PrgP_stats_passing               1
# Rk_stats_passing_types           0
# Nation_stats_passing_types       3
# Pos_stats_passing_types          0
# Comp_stats_passing_types         0
# Age_stats_passing_types          4
# Born_stats_passing_types         4
# 90s_stats_passing_types          0
# Att_stats_passing_types          1
# Live                             1
# Dead                             1
# FK_stats_passing_types           1
# TB                               1
# Sw                               1
# Crs                              0
# TI                               1
# CK                               1
# In                               1
# Out                              1
# Str                              1
# Cmp_stats_passing_types          1
# Off                              1
# Blocks                           1
# Rk_stats_gca                     0
# Nation_stats_gca                 3
# Pos_stats_gca                    0
# Comp_stats_gca                   0
# Age_stats_gca                    4
# Born_stats_gca                   4
# 90s_stats_gca                    0
# SCA                              1
# SCA90                            1
# PassLive                         1
# PassDead                         1
# TO                               1
# Sh_stats_gca                     1
# Fld                              1
# Def                              1
# GCA                              1
# GCA90                            1
# Rk_stats_defense                 0
# Nation_stats_defense             3
# Pos_stats_defense                0
# Comp_stats_defense               0
# Age_stats_defense                4
# Born_stats_defense               4
# 90s_stats_defense                0
# Tkl                              1
# TklW                             0
# Def 3rd                          1
# Mid 3rd                          1
# Att 3rd                          1
# Att_stats_defense                1
# Tkl%                           338
# Lost                             1
# Blocks_stats_defense             1
# Sh_stats_defense                 1
# Pass                             1
# Int                              0
# Tkl+Int                          1
# Clr                              1
# Err                              1
# Rk_stats_possession              0
# Nation_stats_possession          3
# Pos_stats_possession             0
# Comp_stats_possession            0
# Age_stats_possession             4
# Born_stats_possession            4
# 90s_stats_possession             0
# Touches                          1
# Def Pen                          1
# Def 3rd_stats_possession         1
# Mid 3rd_stats_possession         1
# Att 3rd_stats_possession         1
# Att Pen                          1
# Live_stats_possession            1
# Att_stats_possession             1
# Succ                             1
# Succ%                          439
# Tkld                             1
# Tkld%                          439
# Carries                          1
# TotDist_stats_possession         1
# PrgDist_stats_possession         1
# PrgC_stats_possession            1
# 1/3_stats_possession             1
# CPA                              1
# Mis                              1
# Dis                              1
# Rec                              1
# PrgR_stats_possession            1
# Rk_stats_playing_time            0
# Nation_stats_playing_time        3
# Pos_stats_playing_time           0
# Comp_stats_playing_time          0
# Age_stats_playing_time           4
# Born_stats_playing_time          4
# MP_stats_playing_time            0
# Min_stats_playing_time           0
# Mn/MP                            0
# Min%                             0
# 90s_stats_playing_time           0
# Starts_stats_playing_time        0
# Mn/Start                       380
# Compl                            0
# Subs                             0
# Mn/Sub                         448
# unSub                            0
# PPM                              0
# onG                              0
# onGA                             0
# +/-                              0
# +/-90                            0
# On-Off                          31
# onxG                             1
# onxGA                            1
# xG+/-                            1
# xG+/-90                          1
# Rk_stats_misc                    0
# Nation_stats_misc                3
# Pos_stats_misc                   0
# Comp_stats_misc                  0
# Age_stats_misc                   4
# Born_stats_misc                  4
# 90s_stats_misc                   0
# CrdY_stats_misc                  0
# CrdR_stats_misc                  0
# 2CrdY                            0
# Fls                              0
# Fld_stats_misc                   0
# Off_stats_misc                   0
# Crs_stats_misc                   0
# Int_stats_misc                   0
# TklW_stats_misc                  0
# PKwon                            1
# PKcon                            1
# OG                               0
# Recov                            1
# Won                              1
# Lost_stats_misc                  1
# Won%                           218
# Rk_stats_keeper               2585
# Nation_stats_keeper           2585
# Pos_stats_keeper              2585
# Comp_stats_keeper             2585
# Age_stats_keeper              2585
# Born_stats_keeper             2585
# MP_stats_keeper               2585
# Starts_stats_keeper           2585
# Min_stats_keeper              2585
# 90s_stats_keeper              2585
# GA                            2585
# GA90                          2585
# SoTA                          2585
# Saves                         2585
# Save%                         2588
# W                             2585
# D                             2585
# L                             2585
# CS                            2585
# CS%                           2590
# PKatt_stats_keeper            2585
# PKA                           2585
# PKsv                          2585
# PKm                           2585
# Rk_stats_keeper_adv           2585
# Nation_stats_keeper_adv       2585
# Pos_stats_keeper_adv          2585
# Comp_stats_keeper_adv         2585
# Age_stats_keeper_adv          2585
# Born_stats_keeper_adv         2585
# 90s_stats_keeper_adv          2585
# GA_stats_keeper_adv           2585
# PKA_stats_keeper_adv          2585
# FK_stats_keeper_adv           2586
# CK_stats_keeper_adv           2586
# OG_stats_keeper_adv           2586
# PSxG                          2586
# PSxG/SoT                      2589
# PSxG+/-                       2586
# /90                           2586
# Cmp_stats_keeper_adv          2586
# Att_stats_keeper_adv          2586
# Cmp%_stats_keeper_adv         2586
# Att (GK)                      2586
# Thr                           2586
# Launch%                       2586
# AvgLen                        2586
# Opp                           2586
# Stp                           2586
# Stp%                          2586
# #OPA                          2586
# #OPA/90                       2586
# AvgDist                       2587

# %% [markdown]
# ### Diffrent values in non-numeric columns :

# %%
NN_cols = [col for col in df.columns if df[col].dtype == 'object']
NN_cols
# Out:
# ['Player',
#  'Nation',
#  'Pos',
#  'Squad',
#  'Comp',
#  'Nation_stats_shooting',
#  'Pos_stats_shooting',
#  'Comp_stats_shooting',
#  'Age_stats_shooting',
#  'Nation_stats_passing',
#  'Pos_stats_passing',
#  'Comp_stats_passing',
#  'Age_stats_passing',
#  'Nation_stats_passing_types',
#  'Pos_stats_passing_types',
#  'Comp_stats_passing_types',
#  'Age_stats_passing_types',
#  'Nation_stats_gca',
#  'Pos_stats_gca',
#  'Comp_stats_gca',
#  'Age_stats_gca',
#  'Nation_stats_defense',
#  'Pos_stats_defense',
#  'Comp_stats_defense',
#  'Age_stats_defense',
#  'Nation_stats_possession',
#  'Pos_stats_possession',
#  'Comp_stats_possession',
#  'Age_stats_possession',
#  'Nation_stats_playing_time',
#  'Pos_stats_playing_time',
#  'Comp_stats_playing_time',
#  'Age_stats_playing_time',
#  'Nation_stats_misc',
#  'Pos_stats_misc',
#  'Comp_stats_misc',
#  'Age_stats_misc',
#  'Nation_stats_keeper',
#  'Pos_stats_keeper',
#  'Comp_stats_keeper',
#  'Age_stats_keeper',
#  'Nation_stats_keeper_adv',
#  'Pos_stats_keeper_adv',
#  'Comp_stats_keeper_adv',
#  'Age_stats_keeper_adv']

# %%
print(df["Player"].dtype)
# Out:
# object

# %%
for col in NN_cols[:5]:
    print(f'Column name : {col}')
    print(f"this column has {df[col].nunique()} diffrent value ")
# Out:
# Column name : Player
# this column has 2631 diffrent value
# Column name : Nation
# this column has 111 diffrent value
# Column name : Pos
# this column has 10 diffrent value
# Column name : Squad
# this column has 96 diffrent value
# Column name : Comp
# this column has 5 diffrent value

# %%
df[df["Player"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Rk, Player, Nation, Pos, Squad, Comp, Age, Born, MP, Starts, Min, 90s, Gls, Ast, G+A, G-PK, PK, PKatt, CrdY, CrdR, xG, npxG, xAG, npxG+xAG, PrgC, PrgP, PrgR, G+A-PK, xG+xAG, Rk_stats_shooting, Nation_stats_shooting, Pos_stats_shooting, Comp_stats_shooting, Age_stats_shooting, Born_stats_shooting, 90s_stats_shooting, Gls_stats_shooting, Sh, SoT, SoT%, Sh/90, SoT/90, G/Sh, G/SoT, Dist, FK, PK_stats_shooting, PKatt_stats_shooting, xG_stats_shooting, npxG_stats_shooting, npxG/Sh, G-xG, np:G-xG, Rk_stats_passing, Nation_stats_passing, Pos_stats_passing, Comp_stats_passing, Age_stats_passing, Born_stats_passing, 90s_stats_passing, Cmp, Att, Cmp%, TotDist, PrgDist, Ast_stats_passing, xAG_stats_passing, xA, A-xAG, KP, 1/3, PPA, CrsPA, PrgP_stats_passing, Rk_stats_passing_types, Nation_stats_passing_types, Pos_stats_passing_types, Comp_stats_passing_types, Age_stats_passing_types, Born_stats_passing_types, 90s_stats_passing_types, Att_stats_passing_types, Live, Dead, FK_stats_passing_types, TB, Sw, Crs, TI, CK, In, Out, Str, Cmp_stats_passing_types, Off, Blocks, Rk_stats_gca, Nation_stats_gca, Pos_stats_gca, Comp_stats_gca, ...]
# Index: []
#
# [0 rows x 267 columns]

# %% [markdown]
# Duplication maybe !

# %%
#df = df.dropna(subset=['Player'])
value_counts = df['Player'].value_counts()
duplicate_values = value_counts[value_counts > 1].index.tolist()
print("Duplicate values:", duplicate_values)
# Out:
# Duplicate values: ['Max Aarons', 'Odsonne Édouard', 'Michael Folorunsho', 'Evan Ferguson', 'João Félix', 'Nicolò Fagioli', 'Julio Enciso', 'Elif Elmas', 'Anastasios Douvikas', 'Billy Gilmour', 'Niklas Dorsch', 'Patrick Dorgu', 'Axel Disasi', 'Mahamadou Diawara', 'Assane Diao', 'Kevin Danso', 'Valentin Gendrey', 'Ben Godfrey', 'Marco Asensio', 'Jonathan Ikone', 'Abdukodir Khusanov', 'Lloyd Kelly', 'Michael Kayode', 'Jesper Karlsson', 'Juanmi', 'John Joe', 'Arijon Ibrahimović', 'Nicolás González', 'Mario Hermoso', 'Albert Grønbaek', 'Florian Grillitsch', 'Amine Gouiri', 'Robin Gosens', 'Urko González', 'Arnaut Danjuma', 'Danilo', 'Woyo Coulibaly', 'Ismaël Bennacer', 'Warren Bondo', 'Cristiano Biraghi', 'Philip Billing', 'Alessandro Bianco', 'Juan Bernat', 'Mergim Berisha', 'Raoul Bellanova', 'Logan Costa', 'Reda Belahyane', 'Valentín Barco', 'Ridle Baku', 'Mitchel Bakker', 'Juma Bah', 'Adam Aznou', 'Enzo Boyomo', 'Lilian Brassier', 'Jacob Bruun Larsen', 'Tajon Buchanan', 'Emi Buendía', 'Pau Cabanes', 'Davide Calabria', 'Antonio Candela', 'Elia Caprile', 'Maxence Caqueret', 'Irvin Cardona', 'Nicolò Casale', 'Gaetano Castrovilli', 'Trevoh Chalobah', 'Walid Cheddira', 'Chiquinho', 'Maxwel Cornet', 'Joshua King', 'Randal Kolo Muani', 'Ismaël Koné', 'Leo Skiri Østigård', 'Kacper Urbanski', 'Ramón Terrats', 'Mathys Tel', 'Musa Al-Taamari', 'Saidou Sow', 'Riccardo Sottil', 'André Silva', 'Mads Roerslev', 'Baptiste Santamaria', 'Brice Samba', 'Mama Samba Baldé', 'Marco Sala', 'Alexis Saelemaekers', 'Umar Sadiq', 'Siebe Van Der Heyden', 'Ruben Vargas', 'Renato Veiga', 'Gabriel Vidovic', 'Vitinha', 'Alessandro Vogliacco', 'Mërgim Vojvoda', 'Elye Wahi', 'Kyle Walker', 'Sebastian Walukiewicz', 'James Ward-Prowse', 'Noah Weißhaupt', 'Nicola Zalewski', 'Nicolò Zaniolo', 'Alessio Zerbin', 'Kevin Zeroli', 'Cedric Zesiger', 'Anthony Rouault', 'Rodri', 'Christian Kouamé', 'Orel Mangala', 'Bamo Meïté', 'Scott McTominay', 'Omar Marmoush', 'Mirko Marić', 'Pablo Marí', 'Alessandro Marcandalli', 'Lennard Maloney', 'Luis Rioja', 'Donyell Malen', 'Daniel Maldini', 'Iker Losada', 'David López', 'Khvicha Kvaratskhelia', 'Frans Krätzig', 'Marshall Munetsi', 'Juan Musso', 'Junior Mwanga', 'Kosta Nedeljković', 'Reiss Nelson', 'Arnaud Nordin', 'Noah Okafor', 'Frank Onyeka', 'Gift Orban', 'Salih Özcan', 'Tomás Palacios', 'Jordan Pefok', 'Andy Pelmard', 'Kike Pérez', 'Jaden Philogene Bidace', 'Stefan Posch', 'Marcus Rashford', 'Jordan Ayew', 'Milan Đurić', 'Carles Aleñá', 'Antony', 'Emmanuel Agbadou', 'Samuel Amo-Ameyaw', 'Carlos Alcaraz', 'Mathis Amougou', 'Joseph Aidoo', 'Tammy Abraham', 'Joachim Andersen', 'Akor Adams']

# %%
df[df["Player"]=="Vitinha"]
# Out:
#         Rk   Player  Nation    Pos      Squad        Comp   Age    Born  MP  \
# 2647  2648  Vitinha  pt POR  FW,MF      Genoa  it Serie A  25.0  2000.0  18
# 2648  2649  Vitinha  pt POR     MF  Paris S-G  fr Ligue 1  25.0  2000.0  25
#
#       Starts  ...  Att (GK)  Thr  Launch%  AvgLen  Opp  Stp  Stp%  #OPA  \
# 2647      11  ...       NaN  NaN      NaN     NaN  NaN  NaN   NaN   NaN
# 2648      17  ...       NaN  NaN      NaN     NaN  NaN  NaN   NaN   NaN
#
#       #OPA/90  AvgDist
# 2647      NaN      NaN
# 2648      NaN      NaN
#
# [2 rows x 267 columns]

# %%
df[df["Player"]=='Amine Gouiri']
# Out:
#         Rk        Player  Nation    Pos      Squad        Comp   Age    Born  \
# 1021  1022  Amine Gouiri  dz ALG  FW,MF  Marseille  fr Ligue 1  25.0  2000.0
# 1022  1023  Amine Gouiri  dz ALG  MF,FW     Rennes  fr Ligue 1  25.0  2000.0
#
#       MP  Starts  ...  Att (GK)  Thr  Launch%  AvgLen  Opp  Stp  Stp%  #OPA  \
# 1021   8       7  ...       NaN  NaN      NaN     NaN  NaN  NaN   NaN   NaN
# 1022  19      11  ...       NaN  NaN      NaN     NaN  NaN  NaN   NaN   NaN
#
#       #OPA/90  AvgDist
# 1021      NaN      NaN
# 1022      NaN      NaN
#
# [2 rows x 267 columns]

# %%
duplicate_rows = df[df.duplicated(keep=False)]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Rk, Player, Nation, Pos, Squad, Comp, Age, Born, MP, Starts, Min, 90s, Gls, Ast, G+A, G-PK, PK, PKatt, CrdY, CrdR, xG, npxG, xAG, npxG+xAG, PrgC, PrgP, PrgR, G+A-PK, xG+xAG, Rk_stats_shooting, Nation_stats_shooting, Pos_stats_shooting, Comp_stats_shooting, Age_stats_shooting, Born_stats_shooting, 90s_stats_shooting, Gls_stats_shooting, Sh, SoT, SoT%, Sh/90, SoT/90, G/Sh, G/SoT, Dist, FK, PK_stats_shooting, PKatt_stats_shooting, xG_stats_shooting, npxG_stats_shooting, npxG/Sh, G-xG, np:G-xG, Rk_stats_passing, Nation_stats_passing, Pos_stats_passing, Comp_stats_passing, Age_stats_passing, Born_stats_passing, 90s_stats_passing, Cmp, Att, Cmp%, TotDist, PrgDist, Ast_stats_passing, xAG_stats_passing, xA, A-xAG, KP, 1/3, PPA, CrsPA, PrgP_stats_passing, Rk_stats_passing_types, Nation_stats_passing_types, Pos_stats_passing_types, Comp_stats_passing_types, Age_stats_passing_types, Born_stats_passing_types, 90s_stats_passing_types, Att_stats_passing_types, Live, Dead, FK_stats_passing_types, TB, Sw, Crs, TI, CK, In, Out, Str, Cmp_stats_passing_types, Off, Blocks, Rk_stats_gca, Nation_stats_gca, Pos_stats_gca, Comp_stats_gca, ...]
# Index: []
#
# [0 rows x 267 columns]

# %% [markdown]
# since there's no identical raws so the duplications are due to some players who changed club in this periode

# %%
for col in NN_cols[1:5]:
    print(f' Column name : {col}')
    print(f'values:{df[col].value_counts()}')
    print("#"* 60)
# Out:
#  Column name : Nation
# values:Nation
# es ESP     399
# fr FRA     338
# de GER     227
# eng ENG    219
# it ITA     219
#           ...
# cy CYP       1
# cr CRC       1
# lt LTU       1
# do DOM       1
# mt MLT       1
# Name: count, Length: 111, dtype: int64
# ############################################################
#  Column name : Pos
# values:Pos
# DF       841
# MF       584
# FW       364
# FW,MF    303
# MF,FW    240
# GK       197
# DF,MF    108
# MF,DF     66
# DF,FW     52
# FW,DF     27
# Name: count, dtype: int64
# ############################################################
#  Column name : Squad
# values:Squad
# Como               38
# Venezia            36
# Monza              35
# Valladolid         35
# Rennes             35
#                    ..
# Arsenal            24
# Liverpool          24
# Leverkusen         23
# Werder Bremen      23
# Nott'ham Forest    23
# Name: count, Length: 96, dtype: int64
# ############################################################
#  Column name : Comp
# values:Comp
# it Serie A            619
# es La Liga            581
# eng Premier League    558
# fr Ligue 1            541
# de Bundesliga         483
# Name: count, dtype: int64
# ############################################################

# %%
focus_metrics = [
    # Basic Info
    'Age',  
    'MP',              # Matches Played
    'Starts',
    'Min',             # Minutes Played
    '90s',             # Minutes in 90s increments
    
    # Attacking Output
    'Gls',             # Goals
    'Ast',             # Assists
    'G+A',             # Goals + Assists
    'G-PK',            # Non-Penalty Goals
    'xG',              # Expected Goals
    'npxG',            # Non-Penalty xG
    'xAG',             # Expected Assisted Goals
    'npxG+xAG',        # Non-Penalty xG + xA
    'G+A-PK',          # Non-Penalty Goals + Assists
    'xG+xAG',          # Total Expected Contribution
    
    # Set Pieces
    'PK',              # Penalty Goals
    'PKatt',           # Penalty Attempts
    
    # Progression
    'PrgC',            # Progressive Carries
    'PrgP',            # Progressive Passes
    'PrgR',            # Progressive Receives
    
    # Discipline
    'CrdY',            # Yellow Cards
    'CrdR',            # Red Cards
    
    # Advanced Shooting (if available)
    'Sh/90',           # Shots per 90
    'SoT%',            # Shot on Target %
    'G/Sh',            # Goals per Shot
    'Dist',            # Avg Shot Distance
]

# %%
df2=df[focus_metrics]

# %%
df2.describe()
# Out:
#                Age           MP       Starts          Min          90s  \
# count  2778.000000  2782.000000  2782.000000  2782.000000  2782.000000
# mean     25.805976    15.783968    11.213515  1006.642344    11.183501
# std       4.455373     9.378745     9.374105   796.856386     8.853981
# min      16.000000     1.000000     0.000000     1.000000     0.000000
# 25%      22.000000     7.000000     2.000000   273.250000     3.000000
# 50%      25.500000    17.000000     9.000000   870.500000     9.700000
# 75%      29.000000    24.000000    19.000000  1669.500000    18.575000
# max      42.000000    31.000000    31.000000  2790.000000    31.000000
#
#                Gls          Ast          G+A         G-PK           xG  ...  \
# count  2782.000000  2782.000000  2782.000000  2782.000000  2781.000000  ...
# mean      1.399353     0.984543     2.383896     1.276060     1.428047  ...
# std       2.676581     1.621983     3.789784     2.362203     2.377904  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.000000     0.000000     0.000000     0.000000     0.100000  ...
# 50%       0.000000     0.000000     1.000000     0.000000     0.500000  ...
# 75%       2.000000     1.000000     3.000000     2.000000     1.700000  ...
# max      27.000000    17.000000    44.000000    22.000000    24.000000  ...
#
#              PKatt         PrgC         PrgP         PrgR         CrdY  \
# count  2782.000000  2781.000000  2781.000000  2781.000000  2782.000000
# mean      0.157441    17.270406    37.714851    37.365336     2.123293
# std       0.688698    22.314807    41.441989    49.843434     2.235401
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     5.000000     2.000000     0.000000
# 50%       0.000000     9.000000    24.000000    16.000000     2.000000
# 75%       0.000000    24.000000    58.000000    56.000000     3.000000
# max       9.000000   166.000000   294.000000   384.000000    13.000000
#
#               CrdR        Sh/90         SoT%         G/Sh         Dist
# count  2782.000000  2782.000000  2269.000000  2269.000000  2269.000000
# mean      0.095615     1.307344    30.163376     0.081238    17.275716
# std       0.319883     2.386027    21.846251     0.117594     5.403836
# min       0.000000     0.000000     0.000000     0.000000     1.200000
# 25%       0.000000     0.290000    16.700000     0.000000    13.500000
# 50%       0.000000     0.845000    30.600000     0.050000    16.900000
# 75%       0.000000     1.870000    41.100000     0.130000    20.700000
# max       3.000000    90.000000   100.000000     1.000000    40.800000
#
# [8 rows x 26 columns]

# %%
df2.corr()
# Out:
#                Age        MP    Starts       Min       90s       Gls  \
# Age       1.000000  0.215898  0.223158  0.227671  0.227716  0.046835
# MP        0.215898  1.000000  0.888973  0.911045  0.911030  0.436176
# Starts    0.223158  0.888973  1.000000  0.993272  0.993260  0.399385
# Min       0.227671  0.911045  0.993272  1.000000  0.999995  0.392929
# 90s       0.227716  0.911030  0.993260  0.999995  1.000000  0.392880
# Gls       0.046835  0.436176  0.399385  0.392929  0.392880  1.000000
# Ast       0.064273  0.503078  0.473043  0.467972  0.467953  0.526049
# G+A       0.060587  0.523366  0.484527  0.477797  0.477755  0.931405
# G-PK      0.027814  0.446132  0.403744  0.397264  0.397209  0.979928
# xG        0.061746  0.472484  0.419254  0.414306  0.414275  0.925710
# npxG      0.044976  0.489051  0.427194  0.422687  0.422651  0.899383
# xAG       0.065902  0.571019  0.531339  0.527440  0.527404  0.580765
# npxG+xAG  0.059319  0.579036  0.520319  0.515657  0.515617  0.854252
# G+A-PK   -0.035479  0.135069  0.044119  0.046792  0.046806  0.425295
# xG+xAG   -0.046578  0.081391 -0.051861 -0.046413 -0.046401  0.440217
# PK        0.100450  0.191307  0.194093  0.190770  0.190770  0.609240
# PKatt     0.098746  0.207129  0.209563  0.204982  0.204987  0.632433
# PrgC     -0.006585  0.594931  0.564272  0.561077  0.560967  0.510643
# PrgP      0.149321  0.676469  0.713183  0.714016  0.714006  0.293471
# PrgR      0.016839  0.569771  0.497739  0.492226  0.492144  0.653565
# CrdY      0.136593  0.606937  0.613838  0.616022  0.616117  0.187869
# CrdR      0.015052  0.144243  0.150399  0.143977  0.143985  0.018803
# Sh/90    -0.093487 -0.030585 -0.098464 -0.097418 -0.097432  0.187045
# SoT%     -0.037637  0.047171  0.006545  0.008569  0.008618  0.228798
# G/Sh     -0.011402  0.107337  0.068818  0.070432  0.070347  0.399426
# Dist     -0.012295 -0.004856 -0.013506 -0.024921 -0.025024 -0.114549
#
#                Ast       G+A      G-PK        xG  ...     PKatt      PrgC  \
# Age       0.064273  0.060587  0.027814  0.061746  ...  0.098746 -0.006585
# MP        0.503078  0.523366  0.446132  0.472484  ...  0.207129  0.594931
# Starts    0.473043  0.484527  0.403744  0.419254  ...  0.209563  0.564272
# Min       0.467972  0.477797  0.397264  0.414306  ...  0.204982  0.561077
# 90s       0.467953  0.477755  0.397209  0.414275  ...  0.204987  0.560967
# Gls       0.526049  0.931405  0.979928  0.925710  ...  0.632433  0.510643
# Ast       1.000000  0.799517  0.519355  0.557607  ...  0.326979  0.671583
# G+A       0.799517  1.000000  0.914364  0.892459  ...  0.586606  0.648087
# G-PK      0.519355  0.914364  1.000000  0.896688  ...  0.474351  0.521738
# xG        0.557607  0.892459  0.896688  1.000000  ...  0.650783  0.518042
# npxG      0.555698  0.873047  0.907279  0.980012  ...  0.486912  0.533587
# xAG       0.856540  0.776772  0.579867  0.607929  ...  0.334491  0.779007
# npxG+xAG  0.751630  0.925029  0.859023  0.919670  ...  0.471603  0.702126
# G+A-PK    0.361734  0.455188  0.440120  0.379884  ...  0.181083  0.225593
# xG+xAG    0.320144  0.447934  0.430648  0.497039  ...  0.295479  0.230318
# PK        0.305116  0.560869  0.438929  0.605501  ...  0.963630  0.226195
# PKatt     0.326979  0.586606  0.474351  0.650783  ...  1.000000  0.238413
# PrgC      0.671583  0.648087  0.521738  0.518042  ...  0.238413  1.000000
# PrgP      0.526182  0.432473  0.294698  0.298515  ...  0.159416  0.613543
# PrgR      0.739621  0.778149  0.660353  0.683336  ...  0.344249  0.874011
# CrdY      0.271072  0.248700  0.192667  0.210930  ...  0.084318  0.320969
# CrdR      0.063837  0.040602  0.018829  0.034960  ...  0.009990  0.067015
# Sh/90     0.094400  0.172505  0.189412  0.210843  ...  0.098776  0.082720
# SoT%      0.081844  0.198945  0.241587  0.182786  ...  0.078500  0.080034
# G/Sh      0.091390  0.325192  0.430922  0.246513  ...  0.096710  0.075830
# Dist      0.068799 -0.052451 -0.139360 -0.150083  ...  0.033837  0.096442
#
#               PrgP      PrgR      CrdY      CrdR     Sh/90      SoT%  \
# Age       0.149321  0.016839  0.136593  0.015052 -0.093487 -0.037637
# MP        0.676469  0.569771  0.606937  0.144243 -0.030585  0.047171
# Starts    0.713183  0.497739  0.613838  0.150399 -0.098464  0.006545
# Min       0.714016  0.492226  0.616022  0.143977 -0.097418  0.008569
# 90s       0.714006  0.492144  0.616117  0.143985 -0.097432  0.008618
# Gls       0.293471  0.653565  0.187869  0.018803  0.187045  0.228798
# Ast       0.526182  0.739621  0.271072  0.063837  0.094400  0.081844
# G+A       0.432473  0.778149  0.248700  0.040602  0.172505  0.198945
# G-PK      0.294698  0.660353  0.192667  0.018829  0.189412  0.241587
# xG        0.298515  0.683336  0.210930  0.034960  0.210843  0.182786
# npxG      0.301266  0.695801  0.220677  0.037855  0.216832  0.189770
# xAG       0.614198  0.828012  0.308087  0.054532  0.106906  0.094432
# npxG+xAG  0.474411  0.831283  0.283945  0.049846  0.191057  0.169917
# G+A-PK    0.071409  0.315367  0.005649 -0.012538  0.238034  0.262652
# xG+xAG    0.015465  0.358536 -0.057336 -0.038186  0.691257  0.204721
# PK        0.150478  0.318989  0.080372  0.009851  0.089609  0.070558
# PKatt     0.159416  0.344249  0.084318  0.009990  0.098776  0.078500
# PrgC      0.613543  0.874011  0.320969  0.067015  0.082720  0.080034
# PrgP      1.000000  0.458456  0.554349  0.157188 -0.047641 -0.031551
# PrgR      0.458456  1.000000  0.241279  0.026162  0.140610  0.134344
# CrdY      0.554349  0.241279  1.000000  0.243490 -0.065194 -0.034817
# CrdR      0.157188  0.026162  0.243490  1.000000 -0.027642 -0.011786
# Sh/90    -0.047641  0.140610 -0.065194 -0.027642  1.000000  0.120911
# SoT%     -0.031551  0.134344 -0.034817 -0.011786  0.120911  1.000000
# G/Sh      0.020854  0.140346  0.007916  0.009004  0.017430  0.427922
# Dist      0.133782  0.033182  0.050865 -0.008664 -0.042281 -0.129210
#
#               G/Sh      Dist
# Age      -0.011402 -0.012295
# MP        0.107337 -0.004856
# Starts    0.068818 -0.013506
# Min       0.070432 -0.024921
# 90s       0.070347 -0.025024
# Gls       0.399426 -0.114549
# Ast       0.091390  0.068799
# G+A       0.325192 -0.052451
# G-PK      0.430922 -0.139360
# xG        0.246513 -0.150083
# npxG      0.258344 -0.182663
# xAG       0.102339  0.105964
# npxG+xAG  0.219381 -0.074361
# G+A-PK    0.508083 -0.107791
# xG+xAG    0.197001 -0.158307
# PK        0.087737  0.035812
# PKatt     0.096710  0.033837
# PrgC      0.075830  0.096442
# PrgP      0.020854  0.133782
# PrgR      0.140346  0.033182
# CrdY      0.007916  0.050865
# CrdR      0.009004 -0.008664
# Sh/90     0.017430 -0.042281
# SoT%      0.427922 -0.129210
# G/Sh      1.000000 -0.241525
# Dist     -0.241525  1.000000
#
# [26 rows x 26 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8))
sns.heatmap(df2.corr(),cmap='coolwarm')
plt.title("Correlations map")
plt.show()
